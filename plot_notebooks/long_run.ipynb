# %%
import numpy as np
import matplotlib.pyplot as plt
from pearc19_model import pop_dyn, pop_dyn_cap
from scipy.signal import find_peaks

# %%
t,M,W = pop_dyn_cap(brM = .0001, end_time=500, cap = 500)

plt.figure()
# Plot the moose population
plt.plot(t, M, color = "b", label = "Moose Population")
plt.plot(t, W, color = "r", label = "Wolf Population")

plt.legend()
plt.show()
